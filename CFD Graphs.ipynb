# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, mpld3
import seaborn as sns
import os
import re
# %matplotlib notebook

# %% [markdown]
# # Import Functions

# %%
import Functions as f

# %% [markdown]
# # User Inputs

# %%
# Input folder location
PMF = r"V:\j24130900\OpenFoam\Run\PU_Rough"
#DF = r"V:\j24130900\OpenFoam\Run\PU_Combined"

# Export images (Y/N)
Images = "N"

# Number of vtk's to use for timeseries statistics.
Number = 60

# %% [markdown]
# # Plot Graphs
# ### Functions:
# **f.PlotWaterLevel(folder,points,Name,Images,Reverse,Number,dots)** <br>
# **folder:** Location of run folder *e.g. r"V:\j24130900\OpenFoam\Run\PU_Combined"* <br>
# **points:** Name of output file *e.g. "rwe"* <br>
# **Name:** Name to call figure if output to png *e.g. "Centreline Water Elevation"* <br>
# **Images:** Instruction to export image, *can be "Y" or "N"* <br>
# **Reverse:** This call reverses the orientation of the figure, *can be "Reverse" or False* <br>
# **Number:** This is the number of vtks to use, *e.g. 40* <br>
# **dots:** Whether or not to plot dots, *can be number of dots e.g. 5 or False* <br>
# **sensitivity:** Gap between top water level points to count as outliers, *e.g. 0.2m* <br>
# df,fig = f.PlotWaterLevel(PMF,"lwe","",Images,False,Number,60,0.2)
#
# **f.PlotWaterLevelChange(folder,points,Name,critical,ylabel,Images)** <br>
# **folder:** Location of run folder *e.g. r"V:\j24130900\OpenFoam\Run\PU_Combined"* <br>
# **points:** Name of output file *e.g. "rwe"* <br>
# **Name:** Name to call figure if output to png *e.g. "Centreline Water Elevation"* <br>
# **critical:** Plot a critical water level *e.g. 146.00* <br>
# **ylabel:** Label y axis *e.g. "Elevation (mAOD)"* <br>
# **Images:** Instruction to export image, *can be "Y" or "N"* <br>
#
# f.PlotWaterLevelChange(PMF,"coordse","Centreline Water Elevation",146.3,"Elevation (mAOD)",Images)

# %%
df,fig = f.PlotWaterLevel(PMF,"rwe","",Images,False,Number,60,0.2)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# View Graph Data

# %%
#df['Depth'] = df['Top Water Level'] - df['z']
df['Depth Air'] = df['75% Percentile'] - df['Mean']
df
# Out:
#           x        y         z  Distance (m)        Mean      Max      Min  \
# 0   13.1026  62.0483  144.6500      0.000000  144.882267  144.902  144.874
# 1   13.1673  62.4430  144.2500      0.399968  144.375600  144.585  144.280
# 2   13.3938  63.8236  144.1886      1.799024  144.577317  144.600  144.554
# 3   13.4966  65.8199  144.1009      3.797969  144.349933  144.381  144.331
# 4   13.3775  67.8153  144.0132      5.796920  144.190117  144.310  144.112
# 5   13.0379  69.7852  143.9254      7.795879  144.059983  144.168  144.010
# 6   12.4819  71.7053  143.8377      9.794858  144.018983  144.323  143.839
# 7   11.7164  73.5519  143.7500     11.793839  144.207633  144.687  143.815
# 8   10.7509  75.3023  143.5093     13.792861  144.359333  144.668  143.901
# 9    9.5973  76.9347  143.2686     15.791741  144.265233  144.450  143.858
# 10   9.2362  77.3754  143.2000     16.361487  144.149117  144.283  144.071
# ...

# %% [markdown]
# Export Graph to .csv

# %%
location = r"\\global\europe\Cardiff\Jobs\241000\241309-00\4 Internal Project Data\4-40 Calculations\4-11 Wall Heights"
filename = "DFrwe"
f.csvexport(location,df,filename)

# %% [markdown]
# Export Graph to .html

# %%
mpld3.save_html(fig,"Graph3.html")

# %%
f.PlotWaterLevelChange(PMF,"lwe","Left Water Elevation",137.5,"Elevation (mAOD)",Images)
# Out:
# <img src="data:image/png;base64,..." width="640">
